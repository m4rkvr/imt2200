# %%
import pandas as pd

# %% [markdown]
# ## Primer dataset - Beneficiarios FONASA 2023

# %%
original1 = False
try:
    with open("../data/originales/Beneficiarios Fonasa 2023.csv", encoding="latin1", errors="ignore") as f:
        df_beneficiarios = pd.read_csv(f, nrows=1000000)
        print("Se cargo la muestra original")
        original1 = True
        # De tener dataset original, indica numero de filas a cargar o quitar nrows para carga completa

except FileNotFoundError:
    print("El archivo original no se encuentra, abriremos muestra") # Muestra de 100000 filas, habilitado para subir a github
    df_beneficiarios = pd.read_csv("../data/sample/beneficiarios_sample.csv", encoding='latin1')
    print("Se cargo la muestra")
# Out:
# Se cargo la muestra original

# %%
df_beneficiarios
# Out:
#         MES_INFORMACION  CÓDIGO_BENEFICIARIO    SEXO    EDAD_TRAMO  \
# 0                202312             71819187  Hombre  40 a 49 años
# 1                202312             80064014  Hombre  40 a 49 años
# 2                202312             87503153   Mujer  50 a 59 años
# 3                202312             71657668   Mujer  40 a 49 años
# 4                202312             75628648   Mujer  40 a 49 años
# ...                 ...                  ...     ...           ...
# 999995           202312             73025460   Mujer  60 a 69 años
# 999996           202312             69309925  Hombre  60 a 69 años
# 999997           202312             81914415  Hombre  60 a 69 años
# 999998           202312             76690915   Mujer  60 a 69 años
# 999999           202312             68537515   Mujer  60 a 69 años
#
#        TITULAR_CARGA TRAMO_FONASA        TRAMO_RENTA NACIONALIDAD  \
# 0            Titular            D  650.001 - 700.000      Chilena
# 1            Titular            D  900.001 - 950.000      Chilena
# 2            Titular            A   Sin Cotizaciones      Chilena
# 3            Titular            A   Sin Cotizaciones      Chilena
# 4            Titular            B        1 - 100.000      Chilena
# ...              ...          ...                ...          ...
# 999995       Titular            B  500.001 - 550.000      Chilena
# 999996       Titular            B  400.001 - 450.000      Chilena
# 999997       Titular            B        1 - 100.000      Chilena
# 999998       Titular            C   Sin Cotizaciones      Chilena
# 999999         Carga            D  150.001 - 200.000      Chilena
#
#                             CARACTERIZACIÓN          TIPO_ASEGURADO  \
# 0                               Dependiente  Trabajador Dependiente
# 1                               Dependiente  Trabajador Dependiente
# 2                       Grupo Hogar Carente                 Carente
# 3                                       Suf                 Carente
# 4                                Pensionado              Pensionado
# ...                                     ...                     ...
# 999995                          Dependiente  Trabajador Dependiente
# 999996  Desempleado Con Seguro De Desempleo  Trabajador Dependiente
# 999997                          Dependiente  Trabajador Dependiente
# 999998                          Dependiente  Trabajador Dependiente
# 999999                          Dependiente  Trabajador Dependiente
#
#        REGIÓN_BENEFICIARIO COMUNA_BENEFICIARIO
# 0               Del Bíobío         Curanilahue
# 1               Del Bíobío          Concepción
# 2          De La Araucanía             Ercilla
# 3          De La Araucanía            Victoria
# 4          De La Araucanía            Victoria
# ...                    ...                 ...
# 999995           Del Maule               Talca
# 999996           Del Maule       Yerbas Buenas
# 999997           Del Maule               Talca
# 999998      De Antofagasta         Antofagasta
# 999999       De Valparaíso           El Quisco
#
# [1000000 rows x 12 columns]

# %%
#revisar si tiene valores nulos
df_beneficiarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   MES_INFORMACION      1000000 non-null  int64
#  1   CÓDIGO_BENEFICIARIO  1000000 non-null  int64
#  2   SEXO                 1000000 non-null  object
#  3   EDAD_TRAMO           1000000 non-null  object
#  4   TITULAR_CARGA        1000000 non-null  object
#  5   TRAMO_FONASA         1000000 non-null  object
#  6   TRAMO_RENTA          1000000 non-null  object
#  7   NACIONALIDAD         1000000 non-null  object
#  8   CARACTERIZACIÓN      1000000 non-null  object
#  9   TIPO_ASEGURADO       1000000 non-null  object
#  10  REGIÓN_BENEFICIARIO  1000000 non-null  object
#  11  COMUNA_BENEFICIARIO  1000000 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 91.6+ MB

# %%
#eliminar las filas con valores nulos
df_beneficiarios_sin_nulos= df_beneficiarios.dropna()
df_beneficiarios_sin_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   MES_INFORMACION      1000000 non-null  int64
#  1   CÓDIGO_BENEFICIARIO  1000000 non-null  int64
#  2   SEXO                 1000000 non-null  object
#  3   EDAD_TRAMO           1000000 non-null  object
#  4   TITULAR_CARGA        1000000 non-null  object
#  5   TRAMO_FONASA         1000000 non-null  object
#  6   TRAMO_RENTA          1000000 non-null  object
#  7   NACIONALIDAD         1000000 non-null  object
#  8   CARACTERIZACIÓN      1000000 non-null  object
#  9   TIPO_ASEGURADO       1000000 non-null  object
#  10  REGIÓN_BENEFICIARIO  1000000 non-null  object
#  11  COMUNA_BENEFICIARIO  1000000 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 91.6+ MB

# %%
#verificar si existen valores duplicados
df_beneficiarios_sin_nulos.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 999995    False
# 999996    False
# 999997    False
# 999998    False
# 999999    False
# Length: 1000000, dtype: bool

# %%
#eliminar las filas duplicadas
df_beneficiarios_limpio = df_beneficiarios_sin_nulos.drop_duplicates()
df_beneficiarios_limpio.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 999995    False
# 999996    False
# 999997    False
# 999998    False
# 999999    False
# Length: 1000000, dtype: bool

# %%
df_beneficiarios_limpio
# Out:
#         MES_INFORMACION  CÓDIGO_BENEFICIARIO    SEXO    EDAD_TRAMO  \
# 0                202312             71819187  Hombre  40 a 49 años
# 1                202312             80064014  Hombre  40 a 49 años
# 2                202312             87503153   Mujer  50 a 59 años
# 3                202312             71657668   Mujer  40 a 49 años
# 4                202312             75628648   Mujer  40 a 49 años
# ...                 ...                  ...     ...           ...
# 999995           202312             73025460   Mujer  60 a 69 años
# 999996           202312             69309925  Hombre  60 a 69 años
# 999997           202312             81914415  Hombre  60 a 69 años
# 999998           202312             76690915   Mujer  60 a 69 años
# 999999           202312             68537515   Mujer  60 a 69 años
#
#        TITULAR_CARGA TRAMO_FONASA        TRAMO_RENTA NACIONALIDAD  \
# 0            Titular            D  650.001 - 700.000      Chilena
# 1            Titular            D  900.001 - 950.000      Chilena
# 2            Titular            A   Sin Cotizaciones      Chilena
# 3            Titular            A   Sin Cotizaciones      Chilena
# 4            Titular            B        1 - 100.000      Chilena
# ...              ...          ...                ...          ...
# 999995       Titular            B  500.001 - 550.000      Chilena
# 999996       Titular            B  400.001 - 450.000      Chilena
# 999997       Titular            B        1 - 100.000      Chilena
# 999998       Titular            C   Sin Cotizaciones      Chilena
# 999999         Carga            D  150.001 - 200.000      Chilena
#
#                             CARACTERIZACIÓN          TIPO_ASEGURADO  \
# 0                               Dependiente  Trabajador Dependiente
# 1                               Dependiente  Trabajador Dependiente
# 2                       Grupo Hogar Carente                 Carente
# 3                                       Suf                 Carente
# 4                                Pensionado              Pensionado
# ...                                     ...                     ...
# 999995                          Dependiente  Trabajador Dependiente
# 999996  Desempleado Con Seguro De Desempleo  Trabajador Dependiente
# 999997                          Dependiente  Trabajador Dependiente
# 999998                          Dependiente  Trabajador Dependiente
# 999999                          Dependiente  Trabajador Dependiente
#
#        REGIÓN_BENEFICIARIO COMUNA_BENEFICIARIO
# 0               Del Bíobío         Curanilahue
# 1               Del Bíobío          Concepción
# 2          De La Araucanía             Ercilla
# 3          De La Araucanía            Victoria
# 4          De La Araucanía            Victoria
# ...                    ...                 ...
# 999995           Del Maule               Talca
# 999996           Del Maule       Yerbas Buenas
# 999997           Del Maule               Talca
# 999998      De Antofagasta         Antofagasta
# 999999       De Valparaíso           El Quisco
#
# [1000000 rows x 12 columns]

# %%
#guardaremos el dataframe limpio en un archivo csv
if original1 == True:
    df_beneficiarios_limpio.to_csv("../data/beneficiarios_original_limpio.csv", encoding='latin1', index=False)
elif original1 == False:
    df_beneficiarios_limpio.to_csv("../data/sample/beneficiarios_sample_limpio.csv", encoding='latin1', index=False)

# %% [markdown]
# ## Segundo dataset - Modalidad Libre Elección 2023

# %%
original2 = False
try:
    with open("../data/originales/export MLE 2023.csv", encoding="latin1", errors="ignore") as f:
        df_MLE = pd.read_csv(f, nrows=1000000)
        print("Se cargo la muestra original")
        original2 = True
        # De tener dataset original, indica numero de filas a cargar o quitar nrows para carga completa

except FileNotFoundError:
    print("El archivo original no se encuentra, abriremos muestra") # Muestra de 100000 filas, habilitado para subir a github
    df_MLE = pd.read_csv("../data/sample/export_MLE_sample.csv", encoding="latin1")
    print("Se cargo la muestra")
# Out:
# Se cargo la muestra original

# %%
df_MLE.shape
# Out:
# (1000000, 13)

# %%
df_MLE
# Out:
#         MES_EMISION  CODIGO_PRESTACIÓN             DESC_SECCION  \
# 0            202305             309022  Exámenes De Diagnóstico
# 1            202305             302023  Exámenes De Diagnóstico
# 2            202305             302023  Exámenes De Diagnóstico
# 3            202305             302023  Exámenes De Diagnóstico
# 4            202305             302023  Exámenes De Diagnóstico
# ...             ...                ...                      ...
# 999995       202308             101301          Atención Médica
# 999996       202308             101301          Atención Médica
# 999997       202308             101308          Atención Médica
# 999998       202308             101308          Atención Médica
# 999999       202308             101308          Atención Médica
#
#                   DESC_ITEM  CODIGO_BENEFICIARIO TRAMO_FONASA    EDAD_TRAMO  \
# 0       Laboratorio Clínico             97481406            D  35 a 39 años
# 1       Laboratorio Clínico             76712895            X  50 a 54 años
# 2       Laboratorio Clínico             69353764            B  50 a 54 años
# 3       Laboratorio Clínico             76007327            B  55 a 59 años
# 4       Laboratorio Clínico             81474165            B  55 a 59 años
# ...                     ...                  ...          ...           ...
# 999995      Consulta Médica             82181868            B  60 a 64 años
# 999996      Consulta Médica             69072699            C  60 a 64 años
# 999997      Consulta Médica             75587862            D  30 a 34 años
# 999998      Consulta Médica             85032515            B  30 a 34 años
# 999999      Consulta Médica             75861667            B  30 a 34 años
#
#           SEXO             REGION_EMISION COMUNA_EMISION  PRESTRACIONES  \
# 0        Mujer  Metropolitana De Santiago    La Cisterna            1.0
# 1       Hombre                De Tarapacá        Iquique            1.0
# 2        Mujer  Metropolitana De Santiago    San Joaquín            1.0
# 3        Mujer                 Del Bíobío    Curanilahue            1.0
# 4        Mujer  Metropolitana De Santiago     Las Condes            1.0
# ...        ...                        ...            ...            ...
# 999995  Hombre  Metropolitana De Santiago   San Bernardo            1.0
# 999996   Mujer                De Tarapacá        Iquique            1.0
# 999997   Mujer               De Los Lagos         Osorno            1.0
# 999998   Mujer  Metropolitana De Santiago       Santiago            1.0
# 999999   Mujer  Metropolitana De Santiago     La Florida            1.0
#
#         MONTO_FAM  MONTO_COPAGO
# 0             890           900
# 1             630          1390
# 2             630          1390
# 3             630          1390
# 4             630          1390
# ...           ...           ...
# 999995      10510          7010
# 999996      10510          7010
# 999997      10510          7010
# 999998      10510          7010
# 999999      10510          7010
#
# [1000000 rows x 13 columns]

# %%
df_MLE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   MES_EMISION          1000000 non-null  int64
#  1   CODIGO_PRESTACIÓN    1000000 non-null  int64
#  2   DESC_SECCION         1000000 non-null  object
#  3   DESC_ITEM            1000000 non-null  object
#  4   CODIGO_BENEFICIARIO  1000000 non-null  int64
#  5   TRAMO_FONASA         999999 non-null   object
#  6   EDAD_TRAMO           999999 non-null   object
#  7   SEXO                 999999 non-null   object
#  8   REGION_EMISION       999999 non-null   object
#  9   COMUNA_EMISION       999999 non-null   object
#  10  PRESTRACIONES        997531 non-null   float64
#  11  MONTO_FAM            1000000 non-null  int64
#  12  MONTO_COPAGO         1000000 non-null  int64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 99.2+ MB

# %%
#revisar si tiene valores nulos
df_MLE.isnull().values.any()
# Out:
# np.True_

# %%
# ver cuantos valores nulos hay por columna
df_MLE.isnull().sum()
# Out:
# MES_EMISION               0
# CODIGO_PRESTACIÓN         0
# DESC_SECCION              0
# DESC_ITEM                 0
# CODIGO_BENEFICIARIO       0
# TRAMO_FONASA              1
# EDAD_TRAMO                1
# SEXO                      1
# REGION_EMISION            1
# COMUNA_EMISION            1
# PRESTRACIONES          2469
# MONTO_FAM                 0
# MONTO_COPAGO              0
# dtype: int64

# %%
#eliminar las filas con valores nulos
df_MLE_sin_nulos= df_MLE.dropna()
df_MLE_sin_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 997529 entries, 0 to 999999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   MES_EMISION          997529 non-null  int64
#  1   CODIGO_PRESTACIÓN    997529 non-null  int64
#  2   DESC_SECCION         997529 non-null  object
#  3   DESC_ITEM            997529 non-null  object
#  4   CODIGO_BENEFICIARIO  997529 non-null  int64
#  5   TRAMO_FONASA         997529 non-null  object
#  6   EDAD_TRAMO           997529 non-null  object
#  7   SEXO                 997529 non-null  object
#  8   REGION_EMISION       997529 non-null  object
#  9   COMUNA_EMISION       997529 non-null  object
#  10  PRESTRACIONES        997529 non-null  float64
#  11  MONTO_FAM            997529 non-null  int64
#  12  MONTO_COPAGO         997529 non-null  int64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 106.5+ MB

# %%
#reviasr si existen valores duplicados
df_MLE_sin_nulos.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 999995    False
# 999996    False
# 999997    False
# 999998    False
# 999999    False
# Length: 997529, dtype: bool

# %%
# eliminar las filas duplicadas
df_MLE_limpio = df_MLE_sin_nulos.drop_duplicates()
df_MLE_limpio.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 999995    False
# 999996    False
# 999997    False
# 999998    False
# 999999    False
# Length: 997529, dtype: bool

# %%
df_MLE_limpio = df_MLE_limpio.rename(columns={'PRESTRACIONES': 'PRESTACIONES'})

# %%
df_MLE_limpio
# Out:
#         MES_EMISION  CODIGO_PRESTACIÓN             DESC_SECCION  \
# 0            202305             309022  Exámenes De Diagnóstico
# 1            202305             302023  Exámenes De Diagnóstico
# 2            202305             302023  Exámenes De Diagnóstico
# 3            202305             302023  Exámenes De Diagnóstico
# 4            202305             302023  Exámenes De Diagnóstico
# ...             ...                ...                      ...
# 999995       202308             101301          Atención Médica
# 999996       202308             101301          Atención Médica
# 999997       202308             101308          Atención Médica
# 999998       202308             101308          Atención Médica
# 999999       202308             101308          Atención Médica
#
#                   DESC_ITEM  CODIGO_BENEFICIARIO TRAMO_FONASA    EDAD_TRAMO  \
# 0       Laboratorio Clínico             97481406            D  35 a 39 años
# 1       Laboratorio Clínico             76712895            X  50 a 54 años
# 2       Laboratorio Clínico             69353764            B  50 a 54 años
# 3       Laboratorio Clínico             76007327            B  55 a 59 años
# 4       Laboratorio Clínico             81474165            B  55 a 59 años
# ...                     ...                  ...          ...           ...
# 999995      Consulta Médica             82181868            B  60 a 64 años
# 999996      Consulta Médica             69072699            C  60 a 64 años
# 999997      Consulta Médica             75587862            D  30 a 34 años
# 999998      Consulta Médica             85032515            B  30 a 34 años
# 999999      Consulta Médica             75861667            B  30 a 34 años
#
#           SEXO             REGION_EMISION COMUNA_EMISION  PRESTACIONES  \
# 0        Mujer  Metropolitana De Santiago    La Cisterna           1.0
# 1       Hombre                De Tarapacá        Iquique           1.0
# 2        Mujer  Metropolitana De Santiago    San Joaquín           1.0
# 3        Mujer                 Del Bíobío    Curanilahue           1.0
# 4        Mujer  Metropolitana De Santiago     Las Condes           1.0
# ...        ...                        ...            ...           ...
# 999995  Hombre  Metropolitana De Santiago   San Bernardo           1.0
# 999996   Mujer                De Tarapacá        Iquique           1.0
# 999997   Mujer               De Los Lagos         Osorno           1.0
# 999998   Mujer  Metropolitana De Santiago       Santiago           1.0
# 999999   Mujer  Metropolitana De Santiago     La Florida           1.0
#
#         MONTO_FAM  MONTO_COPAGO
# 0             890           900
# 1             630          1390
# 2             630          1390
# 3             630          1390
# 4             630          1390
# ...           ...           ...
# 999995      10510          7010
# 999996      10510          7010
# 999997      10510          7010
# 999998      10510          7010
# 999999      10510          7010
#
# [997529 rows x 13 columns]

# %%
#guardaremos el dataframe limpio en un archivo csv
if original2 == True:
    df_MLE_limpio.to_csv("../data/MLE_2023_original_limpio.csv", encoding='latin1', index=False)
elif original2 == False:
    df_MLE_limpio.to_csv("../data/sample/MLE_2023_sample_limpio.csv", encoding='latin1', index=False)

# %% [markdown]
# ## Tercer Dataframe - Presupuestos MLE 2023

# %%
codigos_df = pd.read_excel("../data/originales/2 Planilla MLE 2023.xlsx", engine='openpyxl')

# %%
# Eliminamos codigos repetidos
codigos_df = codigos_df[~codigos_df["total1"].isin([0])].copy()

# Formateamos codigos a GSSPPP
codigos_df["CODIGO_PRESTACIÓN"] = (
    codigos_df['grupo'].astype(str).str.zfill(1) +
    codigos_df['sub_grupo'].astype(str).str.zfill(2) +
    codigos_df['presta'].astype(str).str.zfill(3)
)
codigos_df = codigos_df.rename(columns={"glosa": "NOMBRE_PRESTACIÓN"})

nombre_codigos = codigos_df[["CODIGO_PRESTACIÓN", "NOMBRE_PRESTACIÓN"]]

# %%
print(nombre_codigos['CODIGO_PRESTACIÓN'].duplicated().sum())
# Out:
# 0

# %%
codigos_df.sample(5)
# Out:
#       secuencia  grupo  sub_grupo  presta  corr  titulo   anes1  anesben1  \
# 3611       3612     21          4     136     0       5   39710     19860
# 2846       2847     18          1      24     0       5       0         0
# 3255       3256     20          1       7     0       5       0         0
# 3863       3864     23          1      44     0       5       0         0
# 2269       2270     15          2      46     0       5  116220     58110
#
#        anes2  anesben2  ...  valcir21  valcir22  valcir23  valcir31 valcir32  \
# 3611   51620     31770  ...     33684     43790     53895     26948    35032
# 2846       0         0  ...         0         0         0         0        0
# 3255       0         0  ...         0         0         0         0        0
# 3863       0         0  ...         0         0         0         0        0
# 2269  151090     92980  ...     77740    101062    124383     62192    80850
#
#       valcir33  valcir41  valcir42  valcir43  CODIGO_PRESTACIÓN
# 3611     43116         0         0         0            2104136
# 2846         0         0         0         0            1801024
# 3255         0         0         0         0            2001007
# 3863         0         0         0         0            2301044
# 2269     99506         0         0         0            1502046
#
# [5 rows x 34 columns]

# %%
codigos_df.to_csv("../data/Presupuestos_MLE_2023_original_limpio.csv", encoding='latin1', index=False)

# %% [markdown]
# **Hacemos merge df_MLE_limpio y nombre_codigos; y añadimos columna "NOMRE_PRESTACION" al df_MLE_limpio**

# %%
df_MLE_limpio
# Out:
#         MES_EMISION  CODIGO_PRESTACIÓN             DESC_SECCION  \
# 0            202305             309022  Exámenes De Diagnóstico
# 1            202305             302023  Exámenes De Diagnóstico
# 2            202305             302023  Exámenes De Diagnóstico
# 3            202305             302023  Exámenes De Diagnóstico
# 4            202305             302023  Exámenes De Diagnóstico
# ...             ...                ...                      ...
# 999995       202308             101301          Atención Médica
# 999996       202308             101301          Atención Médica
# 999997       202308             101308          Atención Médica
# 999998       202308             101308          Atención Médica
# 999999       202308             101308          Atención Médica
#
#                   DESC_ITEM  CODIGO_BENEFICIARIO TRAMO_FONASA    EDAD_TRAMO  \
# 0       Laboratorio Clínico             97481406            D  35 a 39 años
# 1       Laboratorio Clínico             76712895            X  50 a 54 años
# 2       Laboratorio Clínico             69353764            B  50 a 54 años
# 3       Laboratorio Clínico             76007327            B  55 a 59 años
# 4       Laboratorio Clínico             81474165            B  55 a 59 años
# ...                     ...                  ...          ...           ...
# 999995      Consulta Médica             82181868            B  60 a 64 años
# 999996      Consulta Médica             69072699            C  60 a 64 años
# 999997      Consulta Médica             75587862            D  30 a 34 años
# 999998      Consulta Médica             85032515            B  30 a 34 años
# 999999      Consulta Médica             75861667            B  30 a 34 años
#
#           SEXO             REGION_EMISION COMUNA_EMISION  PRESTACIONES  \
# 0        Mujer  Metropolitana De Santiago    La Cisterna           1.0
# 1       Hombre                De Tarapacá        Iquique           1.0
# 2        Mujer  Metropolitana De Santiago    San Joaquín           1.0
# 3        Mujer                 Del Bíobío    Curanilahue           1.0
# 4        Mujer  Metropolitana De Santiago     Las Condes           1.0
# ...        ...                        ...            ...           ...
# 999995  Hombre  Metropolitana De Santiago   San Bernardo           1.0
# 999996   Mujer                De Tarapacá        Iquique           1.0
# 999997   Mujer               De Los Lagos         Osorno           1.0
# 999998   Mujer  Metropolitana De Santiago       Santiago           1.0
# 999999   Mujer  Metropolitana De Santiago     La Florida           1.0
#
#         MONTO_FAM  MONTO_COPAGO
# 0             890           900
# 1             630          1390
# 2             630          1390
# 3             630          1390
# 4             630          1390
# ...           ...           ...
# 999995      10510          7010
# 999996      10510          7010
# 999997      10510          7010
# 999998      10510          7010
# 999999      10510          7010
#
# [997529 rows x 13 columns]

# %%
df_MLE_limpio['CODIGO_PRESTACIÓN'] = df_MLE_limpio['CODIGO_PRESTACIÓN'].astype(str)
nombre_codigos["CODIGO_PRESTACIÓN"] = nombre_codigos["CODIGO_PRESTACIÓN"].astype(str)

df_MLE_limpio = df_MLE_limpio.merge(nombre_codigos, left_on="CODIGO_PRESTACIÓN", right_on="CODIGO_PRESTACIÓN", how='left')
# Out:
# C:\Users\benja\AppData\Local\Temp\ipykernel_6440\142898981.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nombre_codigos["CODIGO_PRESTACIÓN"] = nombre_codigos["CODIGO_PRESTACIÓN"].astype(str)

# %%
df_MLE_limpio.sample(5)
# Out:
#         MES_EMISION CODIGO_PRESTACIÓN                  DESC_SECCION  \
# 682040       202312            404016       Exámenes De Diagnóstico
# 268719       202306            101001               Atención Médica
# 258259       202312            303027       Exámenes De Diagnóstico
# 344566       202306           1701009  Proc. Apoyo Clínico Y Terap.
# 290810       202301            302032       Exámenes De Diagnóstico
#
#                        DESC_ITEM  CODIGO_BENEFICIARIO TRAMO_FONASA  \
# 682040              Imagenología             74484660            B
# 268719           Consulta Médica             72269458            D
# 258259       Laboratorio Clínico             97871687            D
# 344566  Cardiología Y Neumología             67580460            C
# 290810       Laboratorio Clínico             71573673            D
#
#           EDAD_TRAMO    SEXO             REGION_EMISION COMUNA_EMISION  \
# 682040  60 a 64 años   Mujer  Metropolitana De Santiago       Recoleta
# 268719  40 a 44 años   Mujer                 Del Bíobío     Talcahuano
# 258259  00 a 02 años  Hombre               De Los Lagos   Puerto Montt
# 344566  60 a 64 años   Mujer                 De Atacama        Copiapó
# 290810  45 a 49 años   Mujer             De Antofagasta    Antofagasta
#
#         PRESTACIONES  MONTO_FAM  MONTO_COPAGO  \
# 682040           6.0      52500        115620
# 268719           1.0       6600          7180
# 258259           1.0       2110          3390
# 344566           1.0      11380         25040
# 290810           3.0       1710          3750
#
#                                         NOMBRE_PRESTACIÓN
# 682040  ECOGRAFIA PARTES BLANDAS O MUSCULOESQUELETICA ...
# 268719  CONSULTA MEDICINA GENERAL                     ...
# 258259  TIROXINA O TETRAYODOTIRONINA (T4)             ...
# 344566  MONITOREO DE PRESION ARTERIAL CONTINUO        ...
# 290810  ELECTROLITOS PLASMATICOS (SODIO, POTASIO, CLOR...

# %%
#guardaremos el dataframe limpio en un archivo csv
if original2 == True:
    df_MLE_limpio.to_csv("../data/MLE_2023_original_limpio.csv", encoding='latin1', index=False)
elif original2 == False:
    df_MLE_limpio.to_csv("../data/sample/MLE_2023_sample_limpio.csv", encoding='latin1', index=False)

# %%
df_MLE_limpio
# Out:
#         MES_EMISION CODIGO_PRESTACIÓN             DESC_SECCION  \
# 0            202305            309022  Exámenes De Diagnóstico
# 1            202305            302023  Exámenes De Diagnóstico
# 2            202305            302023  Exámenes De Diagnóstico
# 3            202305            302023  Exámenes De Diagnóstico
# 4            202305            302023  Exámenes De Diagnóstico
# ...             ...               ...                      ...
# 997524       202308            101301          Atención Médica
# 997525       202308            101301          Atención Médica
# 997526       202308            101308          Atención Médica
# 997527       202308            101308          Atención Médica
# 997528       202308            101308          Atención Médica
#
#                   DESC_ITEM  CODIGO_BENEFICIARIO TRAMO_FONASA    EDAD_TRAMO  \
# 0       Laboratorio Clínico             97481406            D  35 a 39 años
# 1       Laboratorio Clínico             76712895            X  50 a 54 años
# 2       Laboratorio Clínico             69353764            B  50 a 54 años
# 3       Laboratorio Clínico             76007327            B  55 a 59 años
# 4       Laboratorio Clínico             81474165            B  55 a 59 años
# ...                     ...                  ...          ...           ...
# 997524      Consulta Médica             82181868            B  60 a 64 años
# 997525      Consulta Médica             69072699            C  60 a 64 años
# 997526      Consulta Médica             75587862            D  30 a 34 años
# 997527      Consulta Médica             85032515            B  30 a 34 años
# 997528      Consulta Médica             75861667            B  30 a 34 años
#
#           SEXO             REGION_EMISION COMUNA_EMISION  PRESTACIONES  \
# 0        Mujer  Metropolitana De Santiago    La Cisterna           1.0
# 1       Hombre                De Tarapacá        Iquique           1.0
# 2        Mujer  Metropolitana De Santiago    San Joaquín           1.0
# 3        Mujer                 Del Bíobío    Curanilahue           1.0
# 4        Mujer  Metropolitana De Santiago     Las Condes           1.0
# ...        ...                        ...            ...           ...
# 997524  Hombre  Metropolitana De Santiago   San Bernardo           1.0
# 997525   Mujer                De Tarapacá        Iquique           1.0
# 997526   Mujer               De Los Lagos         Osorno           1.0
# 997527   Mujer  Metropolitana De Santiago       Santiago           1.0
# 997528   Mujer  Metropolitana De Santiago     La Florida           1.0
#
#         MONTO_FAM  MONTO_COPAGO  \
# 0             890           900
# 1             630          1390
# 2             630          1390
# 3             630          1390
# 4             630          1390
# ...           ...           ...
# 997524      10510          7010
# 997525      10510          7010
# 997526      10510          7010
# 997527      10510          7010
# 997528      10510          7010
#
#                                         NOMBRE_PRESTACIÓN
# 0       ORINA COMPLETA, (INCLUYE COD. 03-09-023 Y 03-0...
# 1       CREATININA EN SANGRE                          ...
# 2       CREATININA EN SANGRE                          ...
# 3       CREATININA EN SANGRE                          ...
# 4       CREATININA EN SANGRE                          ...
# ...                                                   ...
# 997524  CONSULTA MEDICA DE ESPECIALIDAD EN CARDIOLOGIA...
# 997525  CONSULTA MEDICA DE ESPECIALIDAD EN CARDIOLOGIA...
# 997526  CONSULTA MEDICA DE ESPECIALIDAD EN OBSTETRICIA...
# 997527  CONSULTA MEDICA DE ESPECIALIDAD EN OBSTETRICIA...
# 997528  CONSULTA MEDICA DE ESPECIALIDAD EN OBSTETRICIA...
#
# [997529 rows x 14 columns]
