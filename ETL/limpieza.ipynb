# %%
import pandas as pd

# %% [markdown]
# primer dataset

# %%
df_beneficiarios = pd.read_csv("../data/beneficiarios_sample.csv", encoding='latin1')
df_beneficiarios
# Out:
#     MES_INFORMACION  CÓDIGO_BENEFICIARIO    SEXO    EDAD_TRAMO TITULAR_CARGA  \
# 0            202312             71819187  Hombre  40 a 49 años       Titular
# 1            202312             80064014  Hombre  40 a 49 años       Titular
# 2            202312             87503153   Mujer  50 a 59 años       Titular
# 3            202312             71657668   Mujer  40 a 49 años       Titular
# 4            202312             75628648   Mujer  40 a 49 años       Titular
# ..              ...                  ...     ...           ...           ...
# 95           202312             68400895  Hombre  40 a 49 años       Titular
# 96           202312             86602758   Mujer  30 a 39 años       Titular
# 97           202312             76736354   Mujer  30 a 39 años       Titular
# 98           202312             69521217  Hombre  30 a 39 años       Titular
# 99           202312             85022323  Hombre  30 a 39 años       Titular
#
#    TRAMO_FONASA        TRAMO_RENTA NACIONALIDAD            CARACTERIZACIÓN  \
# 0             D  650.001 - 700.000      Chilena                Dependiente
# 1             D  900.001 - 950.000      Chilena                Dependiente
# 2             A   Sin Cotizaciones      Chilena        Grupo Hogar Carente
# 3             A   Sin Cotizaciones      Chilena                        Suf
# 4             B        1 - 100.000      Chilena                 Pensionado
# ..          ...                ...          ...                        ...
# 95            B  800.001 - 850.000      Chilena  Empleado Del Sector Salud
# 96            C   Sin Cotizaciones      Chilena                Dependiente
# 97            B  350.001 - 400.000      Chilena                Dependiente
# 98            C   Sin Cotizaciones      Chilena                Dependiente
# 99            D  850.001 - 900.000      Chilena                Dependiente
#
#             TIPO_ASEGURADO        REGIÓN_BENEFICIARIO COMUNA_BENEFICIARIO
# 0   Trabajador Dependiente                 Del Bíobío         Curanilahue
# 1   Trabajador Dependiente                 Del Bíobío          Concepción
# 2                  Carente            De La Araucanía             Ercilla
# 3                  Carente            De La Araucanía            Victoria
# 4               Pensionado            De La Araucanía            Victoria
# ..                     ...                        ...                 ...
# 95  Trabajador Dependiente  Metropolitana De Santiago               Maipú
# 96  Trabajador Dependiente  Metropolitana De Santiago            Peñaflor
# 97  Trabajador Dependiente  Metropolitana De Santiago    Estación Central
# 98  Trabajador Dependiente  Metropolitana De Santiago    Estación Central
# 99  Trabajador Dependiente  Metropolitana De Santiago       Padre Hurtado
#
# [100 rows x 12 columns]

# %%
#revisar si tiene valores nulos
df_beneficiarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MES_INFORMACION      100 non-null    int64
#  1   CÓDIGO_BENEFICIARIO  100 non-null    int64
#  2   SEXO                 100 non-null    object
#  3   EDAD_TRAMO           100 non-null    object
#  4   TITULAR_CARGA        100 non-null    object
#  5   TRAMO_FONASA         100 non-null    object
#  6   TRAMO_RENTA          100 non-null    object
#  7   NACIONALIDAD         100 non-null    object
#  8   CARACTERIZACIÓN      100 non-null    object
#  9   TIPO_ASEGURADO       100 non-null    object
#  10  REGIÓN_BENEFICIARIO  100 non-null    object
#  11  COMUNA_BENEFICIARIO  100 non-null    object
# dtypes: int64(2), object(10)
# memory usage: 9.5+ KB

# %%
#eliminar las filas con valores nulos
df_beneficiarios_sin_nulos= df_beneficiarios.dropna()
df_beneficiarios_sin_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MES_INFORMACION      100 non-null    int64
#  1   CÓDIGO_BENEFICIARIO  100 non-null    int64
#  2   SEXO                 100 non-null    object
#  3   EDAD_TRAMO           100 non-null    object
#  4   TITULAR_CARGA        100 non-null    object
#  5   TRAMO_FONASA         100 non-null    object
#  6   TRAMO_RENTA          100 non-null    object
#  7   NACIONALIDAD         100 non-null    object
#  8   CARACTERIZACIÓN      100 non-null    object
#  9   TIPO_ASEGURADO       100 non-null    object
#  10  REGIÓN_BENEFICIARIO  100 non-null    object
#  11  COMUNA_BENEFICIARIO  100 non-null    object
# dtypes: int64(2), object(10)
# memory usage: 9.5+ KB

# %%
#verificar si existen valores duplicados
df_beneficiarios_sin_nulos.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
#eliminar las filas duplicadas
df_beneficiarios_limpio = df_beneficiarios_sin_nulos.drop_duplicates()
df_beneficiarios_limpio.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
df_beneficiarios_limpio
# Out:
#     MES_INFORMACION  CÓDIGO_BENEFICIARIO    SEXO    EDAD_TRAMO TITULAR_CARGA  \
# 0            202312             71819187  Hombre  40 a 49 años       Titular
# 1            202312             80064014  Hombre  40 a 49 años       Titular
# 2            202312             87503153   Mujer  50 a 59 años       Titular
# 3            202312             71657668   Mujer  40 a 49 años       Titular
# 4            202312             75628648   Mujer  40 a 49 años       Titular
# ..              ...                  ...     ...           ...           ...
# 95           202312             68400895  Hombre  40 a 49 años       Titular
# 96           202312             86602758   Mujer  30 a 39 años       Titular
# 97           202312             76736354   Mujer  30 a 39 años       Titular
# 98           202312             69521217  Hombre  30 a 39 años       Titular
# 99           202312             85022323  Hombre  30 a 39 años       Titular
#
#    TRAMO_FONASA        TRAMO_RENTA NACIONALIDAD            CARACTERIZACIÓN  \
# 0             D  650.001 - 700.000      Chilena                Dependiente
# 1             D  900.001 - 950.000      Chilena                Dependiente
# 2             A   Sin Cotizaciones      Chilena        Grupo Hogar Carente
# 3             A   Sin Cotizaciones      Chilena                        Suf
# 4             B        1 - 100.000      Chilena                 Pensionado
# ..          ...                ...          ...                        ...
# 95            B  800.001 - 850.000      Chilena  Empleado Del Sector Salud
# 96            C   Sin Cotizaciones      Chilena                Dependiente
# 97            B  350.001 - 400.000      Chilena                Dependiente
# 98            C   Sin Cotizaciones      Chilena                Dependiente
# 99            D  850.001 - 900.000      Chilena                Dependiente
#
#             TIPO_ASEGURADO        REGIÓN_BENEFICIARIO COMUNA_BENEFICIARIO
# 0   Trabajador Dependiente                 Del Bíobío         Curanilahue
# 1   Trabajador Dependiente                 Del Bíobío          Concepción
# 2                  Carente            De La Araucanía             Ercilla
# 3                  Carente            De La Araucanía            Victoria
# 4               Pensionado            De La Araucanía            Victoria
# ..                     ...                        ...                 ...
# 95  Trabajador Dependiente  Metropolitana De Santiago               Maipú
# 96  Trabajador Dependiente  Metropolitana De Santiago            Peñaflor
# 97  Trabajador Dependiente  Metropolitana De Santiago    Estación Central
# 98  Trabajador Dependiente  Metropolitana De Santiago    Estación Central
# 99  Trabajador Dependiente  Metropolitana De Santiago       Padre Hurtado
#
# [100 rows x 12 columns]

# %%
#guardaremos el dataframe limpio en un archivo csv
df_beneficiarios_limpio.to_csv("../data/beneficiarios_sample_limpio.csv", encoding='latin1', index=False)

# %% [markdown]
# segunda dataset

# %%
with open("../data/export MLE 2023.csv",encoding="utf-8", errors="ignore") as f:
    df_MLE = pd.read_csv(f, nrows=800) #800 de datos 
    # es una muy pequeña muestra ya que github no permite subir archivos mayores a 50MB
    # funciona sin nungún problema con muestra mucho más grandes

# %%
df_MLE.shape
# Out:
# (800, 13)

# %%
df_MLE
# Out:
#      MES_EMISION  CODIGO_PRESTACIN           DESC_SECCION           DESC_ITEM  \
# 0         202305            309022  Exmenes De Diagnstico  Laboratorio Clnico
# 1         202305            302023  Exmenes De Diagnstico  Laboratorio Clnico
# 2         202305            302023  Exmenes De Diagnstico  Laboratorio Clnico
# 3         202305            302023  Exmenes De Diagnstico  Laboratorio Clnico
# 4         202305            302023  Exmenes De Diagnstico  Laboratorio Clnico
# ..           ...               ...                    ...                 ...
# 795       202303            101001          Atencin Mdica      Consulta Mdica
# 796       202303            101001          Atencin Mdica      Consulta Mdica
# 797       202303            101001          Atencin Mdica      Consulta Mdica
# 798       202303            101001          Atencin Mdica      Consulta Mdica
# 799       202303            101001          Atencin Mdica      Consulta Mdica
#
#      CODIGO_BENEFICIARIO TRAMO_FONASA   EDAD_TRAMO    SEXO  \
# 0               97481406            D  35 a 39 aos   Mujer
# 1               76712895            X  50 a 54 aos  Hombre
# 2               69353764            B  50 a 54 aos   Mujer
# 3               76007327            B  55 a 59 aos   Mujer
# 4               81474165            B  55 a 59 aos   Mujer
# ..                   ...          ...          ...     ...
# 795             81530409            D  25 a 29 aos   Mujer
# 796             81429362            D  25 a 29 aos   Mujer
# 797             74470827            D  25 a 29 aos   Mujer
# 798             78390065            C  25 a 29 aos   Mujer
# 799             81807958            D  25 a 29 aos  Hombre
#
#                 REGION_EMISION COMUNA_EMISION  PRESTRACIONES  MONTO_FAM  \
# 0    Metropolitana De Santiago    La Cisterna              1        890
# 1                   De Tarapac        Iquique              1        630
# 2    Metropolitana De Santiago     San Joaqun              1        630
# 3                     Del Bobo    Curanilahue              1        630
# 4    Metropolitana De Santiago     Las Condes              1        630
# ..                         ...            ...            ...        ...
# 795  Metropolitana De Santiago           Buin              1       6210
# 796  Metropolitana De Santiago           Maip              1       6210
# 797  Metropolitana De Santiago           Maip              1       6210
# 798  Metropolitana De Santiago           Maip              1       6210
# 799  Metropolitana De Santiago           Maip              1       6210
#
#      MONTO_COPAGO
# 0             900
# 1            1390
# 2            1390
# 3            1390
# 4            1390
# ..            ...
# 795          6750
# 796          6750
# 797          6750
# 798          6750
# 799          6750
#
# [800 rows x 13 columns]

# %%
df_MLE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MES_EMISION          800 non-null    int64
#  1   CODIGO_PRESTACIN     800 non-null    int64
#  2   DESC_SECCION         800 non-null    object
#  3   DESC_ITEM            800 non-null    object
#  4   CODIGO_BENEFICIARIO  800 non-null    int64
#  5   TRAMO_FONASA         800 non-null    object
#  6   EDAD_TRAMO           800 non-null    object
#  7   SEXO                 800 non-null    object
#  8   REGION_EMISION       800 non-null    object
#  9   COMUNA_EMISION       800 non-null    object
#  10  PRESTRACIONES        800 non-null    int64
#  11  MONTO_FAM            800 non-null    int64
#  12  MONTO_COPAGO         800 non-null    int64
# dtypes: int64(6), object(7)
# memory usage: 81.4+ KB

# %%
#revisar si tiene valores nulos
df_MLE.isnull().values.any()
# Out:
# False

# %%
# ver cuantos valores nulos hay por columna
df_MLE.isnull().sum()
# Out:
# MES_EMISION            0
# CODIGO_PRESTACIN       0
# DESC_SECCION           0
# DESC_ITEM              0
# CODIGO_BENEFICIARIO    0
# TRAMO_FONASA           0
# EDAD_TRAMO             0
# SEXO                   0
# REGION_EMISION         0
# COMUNA_EMISION         0
# PRESTRACIONES          0
# MONTO_FAM              0
# MONTO_COPAGO           0
# dtype: int64

# %%
#eliminar las filas con valores nulos
df_MLE_sin_nulos= df_MLE.dropna()
df_MLE_sin_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MES_EMISION          800 non-null    int64
#  1   CODIGO_PRESTACIN     800 non-null    int64
#  2   DESC_SECCION         800 non-null    object
#  3   DESC_ITEM            800 non-null    object
#  4   CODIGO_BENEFICIARIO  800 non-null    int64
#  5   TRAMO_FONASA         800 non-null    object
#  6   EDAD_TRAMO           800 non-null    object
#  7   SEXO                 800 non-null    object
#  8   REGION_EMISION       800 non-null    object
#  9   COMUNA_EMISION       800 non-null    object
#  10  PRESTRACIONES        800 non-null    int64
#  11  MONTO_FAM            800 non-null    int64
#  12  MONTO_COPAGO         800 non-null    int64
# dtypes: int64(6), object(7)
# memory usage: 81.4+ KB

# %%
#reviasr si existen valores duplicados
df_MLE_sin_nulos.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Length: 800, dtype: bool

# %%
# eliminar las filas duplicadas
df_MLE_limpio = df_MLE_sin_nulos.drop_duplicates()
df_MLE_limpio.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Length: 800, dtype: bool

# %%
df_MLE_limpio
# Out:
#      MES_EMISION  CODIGO_PRESTACIN           DESC_SECCION           DESC_ITEM  \
# 0         202305            309022  Exmenes De Diagnstico  Laboratorio Clnico
# 1         202305            302023  Exmenes De Diagnstico  Laboratorio Clnico
# 2         202305            302023  Exmenes De Diagnstico  Laboratorio Clnico
# 3         202305            302023  Exmenes De Diagnstico  Laboratorio Clnico
# 4         202305            302023  Exmenes De Diagnstico  Laboratorio Clnico
# ..           ...               ...                    ...                 ...
# 795       202303            101001          Atencin Mdica      Consulta Mdica
# 796       202303            101001          Atencin Mdica      Consulta Mdica
# 797       202303            101001          Atencin Mdica      Consulta Mdica
# 798       202303            101001          Atencin Mdica      Consulta Mdica
# 799       202303            101001          Atencin Mdica      Consulta Mdica
#
#      CODIGO_BENEFICIARIO TRAMO_FONASA   EDAD_TRAMO    SEXO  \
# 0               97481406            D  35 a 39 aos   Mujer
# 1               76712895            X  50 a 54 aos  Hombre
# 2               69353764            B  50 a 54 aos   Mujer
# 3               76007327            B  55 a 59 aos   Mujer
# 4               81474165            B  55 a 59 aos   Mujer
# ..                   ...          ...          ...     ...
# 795             81530409            D  25 a 29 aos   Mujer
# 796             81429362            D  25 a 29 aos   Mujer
# 797             74470827            D  25 a 29 aos   Mujer
# 798             78390065            C  25 a 29 aos   Mujer
# 799             81807958            D  25 a 29 aos  Hombre
#
#                 REGION_EMISION COMUNA_EMISION  PRESTRACIONES  MONTO_FAM  \
# 0    Metropolitana De Santiago    La Cisterna              1        890
# 1                   De Tarapac        Iquique              1        630
# 2    Metropolitana De Santiago     San Joaqun              1        630
# 3                     Del Bobo    Curanilahue              1        630
# 4    Metropolitana De Santiago     Las Condes              1        630
# ..                         ...            ...            ...        ...
# 795  Metropolitana De Santiago           Buin              1       6210
# 796  Metropolitana De Santiago           Maip              1       6210
# 797  Metropolitana De Santiago           Maip              1       6210
# 798  Metropolitana De Santiago           Maip              1       6210
# 799  Metropolitana De Santiago           Maip              1       6210
#
#      MONTO_COPAGO
# 0             900
# 1            1390
# 2            1390
# 3            1390
# 4            1390
# ..            ...
# 795          6750
# 796          6750
# 797          6750
# 798          6750
# 799          6750
#
# [800 rows x 13 columns]

# %%
#guardaremos el dataframe limpio en un archivo csv
df_MLE_limpio.to_csv("../data/export MLE 2023 limpio.csv", encoding='latin1', index=False)
