# %%
import pandas as pd

# %% [markdown]
# ## Primer dataset - Beneficiarios FONASA 2023

# %%
original1 = False
try:
    with open("../data/originales/Beneficiarios Fonasa 2023.csv", encoding="latin1", errors="ignore") as f:
        df_beneficiarios = pd.read_csv(f, nrows=1000000)
        print("Se cargo la muestra original")
        original1 = True
        # De tener dataset original, indica numero de filas a cargar o quitar nrows para carga completa

except FileNotFoundError:
    print("El archivo original no se encuentra, abriremos muestra") # Muestra de 100000 filas, habilitado para subir a github
    df_beneficiarios = pd.read_csv("../data/sample/beneficiarios_sample.csv", encoding='latin1')
    print("Se cargo la muestra")
# Out:
# El archivo original no se encuentra, abriremos muestra
# Se cargo la muestra

# %%
df_beneficiarios
# Out:
#        MES_INFORMACION  CÓDIGO_BENEFICIARIO    SEXO    EDAD_TRAMO  \
# 0               202312             71819187  Hombre  40 a 49 años
# 1               202312             80064014  Hombre  40 a 49 años
# 2               202312             87503153   Mujer  50 a 59 años
# 3               202312             71657668   Mujer  40 a 49 años
# 4               202312             75628648   Mujer  40 a 49 años
# ...                ...                  ...     ...           ...
# 99995           202312             77002490  Hombre  50 a 59 años
# 99996           202312             71958114   Mujer  50 a 59 años
# 99997           202312             68992350   Mujer  50 a 59 años
# 99998           202312             71182060   Mujer  50 a 59 años
# 99999           202312             67045721   Mujer  50 a 59 años
#
#       TITULAR_CARGA TRAMO_FONASA        TRAMO_RENTA NACIONALIDAD  \
# 0           Titular            D  650.001 - 700.000      Chilena
# 1           Titular            D  900.001 - 950.000      Chilena
# 2           Titular            A   Sin Cotizaciones      Chilena
# 3           Titular            A   Sin Cotizaciones      Chilena
# 4           Titular            B        1 - 100.000      Chilena
# ...             ...          ...                ...          ...
# 99995       Titular            D  900.001 - 950.000      Chilena
# 99996       Titular            B  700.001 - 750.000      Chilena
# 99997       Titular            B  300.001 - 350.000      Chilena
# 99998       Titular            B  600.001 - 650.000      Chilena
# 99999       Titular            C   Sin Cotizaciones      Chilena
#
#               CARACTERIZACIÓN            TIPO_ASEGURADO  \
# 0                 Dependiente    Trabajador Dependiente
# 1                 Dependiente    Trabajador Dependiente
# 2         Grupo Hogar Carente                   Carente
# 3                         Suf                   Carente
# 4                  Pensionado                Pensionado
# ...                       ...                       ...
# 99995             Dependiente    Trabajador Dependiente
# 99996  Trabajador A Honorario  Trabajador Independiente
# 99997             Dependiente    Trabajador Dependiente
# 99998  Trabajador A Honorario  Trabajador Independiente
# 99999             Dependiente    Trabajador Dependiente
#
#                              REGIÓN_BENEFICIARIO COMUNA_BENEFICIARIO
# 0                                     Del Bíobío         Curanilahue
# 1                                     Del Bíobío          Concepción
# 2                                De La Araucanía             Ercilla
# 3                                De La Araucanía            Victoria
# 4                                De La Araucanía            Victoria
# ...                                          ...                 ...
# 99995                  Metropolitana De Santiago           Lo Espejo
# 99996  Del Libertador General Bernardo O'Higgins             Machalí
# 99997  Del Libertador General Bernardo O'Higgins   Quinta De Tilcoco
# 99998                               De Los Lagos           Purranque
# 99999                  Metropolitana De Santiago           Melipilla
#
# [100000 rows x 12 columns]

# %%
#revisar si tiene valores nulos
df_beneficiarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   MES_INFORMACION      100000 non-null  int64
#  1   CÓDIGO_BENEFICIARIO  100000 non-null  int64
#  2   SEXO                 100000 non-null  object
#  3   EDAD_TRAMO           100000 non-null  object
#  4   TITULAR_CARGA        100000 non-null  object
#  5   TRAMO_FONASA         100000 non-null  object
#  6   TRAMO_RENTA          100000 non-null  object
#  7   NACIONALIDAD         100000 non-null  object
#  8   CARACTERIZACIÓN      100000 non-null  object
#  9   TIPO_ASEGURADO       100000 non-null  object
#  10  REGIÓN_BENEFICIARIO  100000 non-null  object
#  11  COMUNA_BENEFICIARIO  100000 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 9.2+ MB

# %%
#eliminar las filas con valores nulos
df_beneficiarios_sin_nulos= df_beneficiarios.dropna()
df_beneficiarios_sin_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   MES_INFORMACION      100000 non-null  int64
#  1   CÓDIGO_BENEFICIARIO  100000 non-null  int64
#  2   SEXO                 100000 non-null  object
#  3   EDAD_TRAMO           100000 non-null  object
#  4   TITULAR_CARGA        100000 non-null  object
#  5   TRAMO_FONASA         100000 non-null  object
#  6   TRAMO_RENTA          100000 non-null  object
#  7   NACIONALIDAD         100000 non-null  object
#  8   CARACTERIZACIÓN      100000 non-null  object
#  9   TIPO_ASEGURADO       100000 non-null  object
#  10  REGIÓN_BENEFICIARIO  100000 non-null  object
#  11  COMUNA_BENEFICIARIO  100000 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 9.2+ MB

# %%
#verificar si existen valores duplicados
df_beneficiarios_sin_nulos.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Length: 100000, dtype: bool

# %%
#eliminar las filas duplicadas
df_beneficiarios_limpio = df_beneficiarios_sin_nulos.drop_duplicates()
df_beneficiarios_limpio.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Length: 100000, dtype: bool

# %%
df_beneficiarios_limpio
# Out:
#        MES_INFORMACION  CÓDIGO_BENEFICIARIO    SEXO    EDAD_TRAMO  \
# 0               202312             71819187  Hombre  40 a 49 años
# 1               202312             80064014  Hombre  40 a 49 años
# 2               202312             87503153   Mujer  50 a 59 años
# 3               202312             71657668   Mujer  40 a 49 años
# 4               202312             75628648   Mujer  40 a 49 años
# ...                ...                  ...     ...           ...
# 99995           202312             77002490  Hombre  50 a 59 años
# 99996           202312             71958114   Mujer  50 a 59 años
# 99997           202312             68992350   Mujer  50 a 59 años
# 99998           202312             71182060   Mujer  50 a 59 años
# 99999           202312             67045721   Mujer  50 a 59 años
#
#       TITULAR_CARGA TRAMO_FONASA        TRAMO_RENTA NACIONALIDAD  \
# 0           Titular            D  650.001 - 700.000      Chilena
# 1           Titular            D  900.001 - 950.000      Chilena
# 2           Titular            A   Sin Cotizaciones      Chilena
# 3           Titular            A   Sin Cotizaciones      Chilena
# 4           Titular            B        1 - 100.000      Chilena
# ...             ...          ...                ...          ...
# 99995       Titular            D  900.001 - 950.000      Chilena
# 99996       Titular            B  700.001 - 750.000      Chilena
# 99997       Titular            B  300.001 - 350.000      Chilena
# 99998       Titular            B  600.001 - 650.000      Chilena
# 99999       Titular            C   Sin Cotizaciones      Chilena
#
#               CARACTERIZACIÓN            TIPO_ASEGURADO  \
# 0                 Dependiente    Trabajador Dependiente
# 1                 Dependiente    Trabajador Dependiente
# 2         Grupo Hogar Carente                   Carente
# 3                         Suf                   Carente
# 4                  Pensionado                Pensionado
# ...                       ...                       ...
# 99995             Dependiente    Trabajador Dependiente
# 99996  Trabajador A Honorario  Trabajador Independiente
# 99997             Dependiente    Trabajador Dependiente
# 99998  Trabajador A Honorario  Trabajador Independiente
# 99999             Dependiente    Trabajador Dependiente
#
#                              REGIÓN_BENEFICIARIO COMUNA_BENEFICIARIO
# 0                                     Del Bíobío         Curanilahue
# 1                                     Del Bíobío          Concepción
# 2                                De La Araucanía             Ercilla
# 3                                De La Araucanía            Victoria
# 4                                De La Araucanía            Victoria
# ...                                          ...                 ...
# 99995                  Metropolitana De Santiago           Lo Espejo
# 99996  Del Libertador General Bernardo O'Higgins             Machalí
# 99997  Del Libertador General Bernardo O'Higgins   Quinta De Tilcoco
# 99998                               De Los Lagos           Purranque
# 99999                  Metropolitana De Santiago           Melipilla
#
# [100000 rows x 12 columns]

# %%
#guardaremos el dataframe limpio en un archivo csv
if original1 == True:
    df_beneficiarios_limpio.to_csv("../data/beneficiarios_original_limpio.csv", encoding='latin1', index=False)
elif original1 == False:
    df_beneficiarios_limpio.to_csv("../data/sample/beneficiarios_sample_limpio.csv", encoding='latin1', index=False)

# %% [markdown]
# ## Segundo dataset - Modalidad Libre Elección 2023

# %%
original2 = False
try:
    with open("../data/originales/export MLE 2023.csv", encoding="latin1", errors="ignore") as f:
        df_MLE = pd.read_csv(f, nrows=1000000)
        print("Se cargo la muestra original")
        original2 = True
        # De tener dataset original, indica numero de filas a cargar o quitar nrows para carga completa

except FileNotFoundError:
    print("El archivo original no se encuentra, abriremos muestra") # Muestra de 100000 filas, habilitado para subir a github
    df_MLE = pd.read_csv("../data/sample/export_MLE_sample.csv", encoding="latin1")
    print("Se cargo la muestra")
# Out:
# El archivo original no se encuentra, abriremos muestra
# Se cargo la muestra

# %%
df_MLE.shape
# Out:
# (100000, 13)

# %%
df_MLE
# Out:
#        MES_EMISION  CODIGO_PRESTACIÓN             DESC_SECCION  \
# 0           202305             309022  Exámenes De Diagnóstico
# 1           202305             302023  Exámenes De Diagnóstico
# 2           202305             302023  Exámenes De Diagnóstico
# 3           202305             302023  Exámenes De Diagnóstico
# 4           202305             302023  Exámenes De Diagnóstico
# ...            ...                ...                      ...
# 99995       202308             101202          Atención Médica
# 99996       202308             101203          Atención Médica
# 99997       202306             101209          Atención Médica
# 99998       202306             101209          Atención Médica
# 99999       202306             101209          Atención Médica
#
#                  DESC_ITEM  CODIGO_BENEFICIARIO TRAMO_FONASA    EDAD_TRAMO  \
# 0      Laboratorio Clínico             97481406            D  35 a 39 años
# 1      Laboratorio Clínico             76712895            X  50 a 54 años
# 2      Laboratorio Clínico             69353764            B  50 a 54 años
# 3      Laboratorio Clínico             76007327            B  55 a 59 años
# 4      Laboratorio Clínico             81474165            B  55 a 59 años
# ...                    ...                  ...          ...           ...
# 99995      Consulta Médica             76391769            D  85 a 89 años
# 99996      Consulta Médica             75506267            D  85 a 89 años
# 99997      Consulta Médica             81255758            D  25 a 29 años
# 99998      Consulta Médica             78171390            D  40 a 44 años
# 99999      Consulta Médica             74643652            B  30 a 34 años
#
#          SEXO             REGION_EMISION COMUNA_EMISION  PRESTRACIONES  \
# 0       Mujer  Metropolitana De Santiago    La Cisterna            1.0
# 1      Hombre                De Tarapacá        Iquique            1.0
# 2       Mujer  Metropolitana De Santiago    San Joaquín            1.0
# 3       Mujer                 Del Bíobío    Curanilahue            1.0
# 4       Mujer  Metropolitana De Santiago     Las Condes            1.0
# ...       ...                        ...            ...            ...
# 99995   Mujer              De Valparaíso  Villa Alemana            1.0
# 99996   Mujer                De Tarapacá          Arica            1.0
# 99997   Mujer                De Los Ríos       Valdivia            1.0
# 99998   Mujer                  Del Maule         Curicó            1.0
# 99999   Mujer  Metropolitana De Santiago    Providencia            1.0
#
#        MONTO_FAM  MONTO_COPAGO
# 0            890           900
# 1            630          1390
# 2            630          1390
# 3            630          1390
# 4            630          1390
# ...          ...           ...
# 99995       9330         15550
# 99996       9330         15550
# 99997       9330         15550
# 99998       9330         15550
# 99999       9330         15550
#
# [100000 rows x 13 columns]

# %%
df_MLE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   MES_EMISION          100000 non-null  int64
#  1   CODIGO_PRESTACIÓN    100000 non-null  int64
#  2   DESC_SECCION         100000 non-null  object
#  3   DESC_ITEM            100000 non-null  object
#  4   CODIGO_BENEFICIARIO  100000 non-null  int64
#  5   TRAMO_FONASA         100000 non-null  object
#  6   EDAD_TRAMO           100000 non-null  object
#  7   SEXO                 100000 non-null  object
#  8   REGION_EMISION       100000 non-null  object
#  9   COMUNA_EMISION       100000 non-null  object
#  10  PRESTRACIONES        99823 non-null   float64
#  11  MONTO_FAM            100000 non-null  int64
#  12  MONTO_COPAGO         100000 non-null  int64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 9.9+ MB

# %%
#revisar si tiene valores nulos
df_MLE.isnull().values.any()
# Out:
# np.True_

# %%
# ver cuantos valores nulos hay por columna
df_MLE.isnull().sum()
# Out:
# MES_EMISION              0
# CODIGO_PRESTACIÓN        0
# DESC_SECCION             0
# DESC_ITEM                0
# CODIGO_BENEFICIARIO      0
# TRAMO_FONASA             0
# EDAD_TRAMO               0
# SEXO                     0
# REGION_EMISION           0
# COMUNA_EMISION           0
# PRESTRACIONES          177
# MONTO_FAM                0
# MONTO_COPAGO             0
# dtype: int64

# %%
#eliminar las filas con valores nulos
df_MLE_sin_nulos= df_MLE.dropna()
df_MLE_sin_nulos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99823 entries, 0 to 99999
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MES_EMISION          99823 non-null  int64
#  1   CODIGO_PRESTACIÓN    99823 non-null  int64
#  2   DESC_SECCION         99823 non-null  object
#  3   DESC_ITEM            99823 non-null  object
#  4   CODIGO_BENEFICIARIO  99823 non-null  int64
#  5   TRAMO_FONASA         99823 non-null  object
#  6   EDAD_TRAMO           99823 non-null  object
#  7   SEXO                 99823 non-null  object
#  8   REGION_EMISION       99823 non-null  object
#  9   COMUNA_EMISION       99823 non-null  object
#  10  PRESTRACIONES        99823 non-null  float64
#  11  MONTO_FAM            99823 non-null  int64
#  12  MONTO_COPAGO         99823 non-null  int64
# dtypes: float64(1), int64(5), object(7)
# memory usage: 10.7+ MB

# %%
#reviasr si existen valores duplicados
df_MLE_sin_nulos.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Length: 99823, dtype: bool

# %%
# eliminar las filas duplicadas
df_MLE_limpio = df_MLE_sin_nulos.drop_duplicates()
df_MLE_limpio.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Length: 99823, dtype: bool

# %%
df_MLE_limpio = df_MLE_limpio.rename(columns={'PRESTRACIONES': 'PRESTACIONES'})

# %%
df_MLE_limpio["REGION_EMISION"] = df_MLE_limpio["REGION_EMISION"].replace({"Ñuble": "De Ñuble"})

# %%
df_MLE_limpio
# Out:
#        MES_EMISION  CODIGO_PRESTACIÓN             DESC_SECCION  \
# 0           202305             309022  Exámenes De Diagnóstico
# 1           202305             302023  Exámenes De Diagnóstico
# 2           202305             302023  Exámenes De Diagnóstico
# 3           202305             302023  Exámenes De Diagnóstico
# 4           202305             302023  Exámenes De Diagnóstico
# ...            ...                ...                      ...
# 99995       202308             101202          Atención Médica
# 99996       202308             101203          Atención Médica
# 99997       202306             101209          Atención Médica
# 99998       202306             101209          Atención Médica
# 99999       202306             101209          Atención Médica
#
#                  DESC_ITEM  CODIGO_BENEFICIARIO TRAMO_FONASA    EDAD_TRAMO  \
# 0      Laboratorio Clínico             97481406            D  35 a 39 años
# 1      Laboratorio Clínico             76712895            X  50 a 54 años
# 2      Laboratorio Clínico             69353764            B  50 a 54 años
# 3      Laboratorio Clínico             76007327            B  55 a 59 años
# 4      Laboratorio Clínico             81474165            B  55 a 59 años
# ...                    ...                  ...          ...           ...
# 99995      Consulta Médica             76391769            D  85 a 89 años
# 99996      Consulta Médica             75506267            D  85 a 89 años
# 99997      Consulta Médica             81255758            D  25 a 29 años
# 99998      Consulta Médica             78171390            D  40 a 44 años
# 99999      Consulta Médica             74643652            B  30 a 34 años
#
#          SEXO             REGION_EMISION COMUNA_EMISION  PRESTACIONES  \
# 0       Mujer  Metropolitana De Santiago    La Cisterna           1.0
# 1      Hombre                De Tarapacá        Iquique           1.0
# 2       Mujer  Metropolitana De Santiago    San Joaquín           1.0
# 3       Mujer                 Del Bíobío    Curanilahue           1.0
# 4       Mujer  Metropolitana De Santiago     Las Condes           1.0
# ...       ...                        ...            ...           ...
# 99995   Mujer              De Valparaíso  Villa Alemana           1.0
# 99996   Mujer                De Tarapacá          Arica           1.0
# 99997   Mujer                De Los Ríos       Valdivia           1.0
# 99998   Mujer                  Del Maule         Curicó           1.0
# 99999   Mujer  Metropolitana De Santiago    Providencia           1.0
#
#        MONTO_FAM  MONTO_COPAGO
# 0            890           900
# 1            630          1390
# 2            630          1390
# 3            630          1390
# 4            630          1390
# ...          ...           ...
# 99995       9330         15550
# 99996       9330         15550
# 99997       9330         15550
# 99998       9330         15550
# 99999       9330         15550
#
# [99823 rows x 13 columns]

# %%
#guardaremos el dataframe limpio en un archivo csv
if original2 == True:
    df_MLE_limpio.to_csv("../data/MLE_2023_original_limpio.csv", encoding='latin1', index=False)
elif original2 == False:
    df_MLE_limpio.to_csv("../data/sample/MLE_2023_sample_limpio.csv", encoding='latin1', index=False)

# %% [markdown]
# ## Tercer Dataframe - Presupuestos MLE 2023

# %%
codigos_df = pd.read_excel("../data/originales/2 Planilla MLE 2023.xlsx", engine='openpyxl')

# %%
# Eliminamos codigos repetidos
codigos_df = codigos_df[~codigos_df["total1"].isin([0])].copy()

# Formateamos codigos a GSSPPP
codigos_df["CODIGO_PRESTACIÓN"] = (
    codigos_df['grupo'].astype(str).str.zfill(1) +
    codigos_df['sub_grupo'].astype(str).str.zfill(2) +
    codigos_df['presta'].astype(str).str.zfill(3)
)
codigos_df = codigos_df.rename(columns={"glosa": "NOMBRE_PRESTACIÓN"})

nombre_codigos = codigos_df[["CODIGO_PRESTACIÓN", "NOMBRE_PRESTACIÓN"]]

# %%
print(nombre_codigos['CODIGO_PRESTACIÓN'].duplicated().sum())
# Out:
# 0

# %%
codigos_df.sample(5)
# Out:
#       secuencia  grupo  sub_grupo  presta  corr  titulo  anes1  anesben1  \
# 722         723      3          6     112     0       5      0         0
# 313         314      3          2      45     0       5      0         0
# 3071       3072     19          1       6     0       5      0         0
# 1478       1479     11          1      44     0       5      0         0
# 1185       1186      5          1     121     0       5      0         0
#
#       anes2  anesben2  ...  valcir21  valcir22  valcir23  valcir31 valcir32  \
# 722       0         0  ...         0         0         0         0        0
# 313       0         0  ...         0         0         0         0        0
# 3071      0         0  ...         0         0         0         0        0
# 1478      0         0  ...         0         0         0         0        0
# 1185      0         0  ...         0         0         0         0        0
#
#       valcir33  valcir41  valcir42  valcir43  CODIGO_PRESTACIÓN
# 722          0         0         0         0             306112
# 313          0         0         0         0             302045
# 3071         0         0         0         0            1901006
# 1478         0         0         0         0            1101044
# 1185         0         0         0         0             501121
#
# [5 rows x 34 columns]

# %%
codigos_df.to_csv("../data/Presupuestos_MLE_2023_original_limpio.csv", encoding='latin1', index=False)

# %% [markdown]
# **Hacemos merge df_MLE_limpio y nombre_codigos; y añadimos columna "NOMRE_PRESTACION" al df_MLE_limpio**

# %%
df_MLE_limpio
# Out:
#        MES_EMISION  CODIGO_PRESTACIÓN             DESC_SECCION  \
# 0           202305             309022  Exámenes De Diagnóstico
# 1           202305             302023  Exámenes De Diagnóstico
# 2           202305             302023  Exámenes De Diagnóstico
# 3           202305             302023  Exámenes De Diagnóstico
# 4           202305             302023  Exámenes De Diagnóstico
# ...            ...                ...                      ...
# 99995       202308             101202          Atención Médica
# 99996       202308             101203          Atención Médica
# 99997       202306             101209          Atención Médica
# 99998       202306             101209          Atención Médica
# 99999       202306             101209          Atención Médica
#
#                  DESC_ITEM  CODIGO_BENEFICIARIO TRAMO_FONASA    EDAD_TRAMO  \
# 0      Laboratorio Clínico             97481406            D  35 a 39 años
# 1      Laboratorio Clínico             76712895            X  50 a 54 años
# 2      Laboratorio Clínico             69353764            B  50 a 54 años
# 3      Laboratorio Clínico             76007327            B  55 a 59 años
# 4      Laboratorio Clínico             81474165            B  55 a 59 años
# ...                    ...                  ...          ...           ...
# 99995      Consulta Médica             76391769            D  85 a 89 años
# 99996      Consulta Médica             75506267            D  85 a 89 años
# 99997      Consulta Médica             81255758            D  25 a 29 años
# 99998      Consulta Médica             78171390            D  40 a 44 años
# 99999      Consulta Médica             74643652            B  30 a 34 años
#
#          SEXO             REGION_EMISION COMUNA_EMISION  PRESTACIONES  \
# 0       Mujer  Metropolitana De Santiago    La Cisterna           1.0
# 1      Hombre                De Tarapacá        Iquique           1.0
# 2       Mujer  Metropolitana De Santiago    San Joaquín           1.0
# 3       Mujer                 Del Bíobío    Curanilahue           1.0
# 4       Mujer  Metropolitana De Santiago     Las Condes           1.0
# ...       ...                        ...            ...           ...
# 99995   Mujer              De Valparaíso  Villa Alemana           1.0
# 99996   Mujer                De Tarapacá          Arica           1.0
# 99997   Mujer                De Los Ríos       Valdivia           1.0
# 99998   Mujer                  Del Maule         Curicó           1.0
# 99999   Mujer  Metropolitana De Santiago    Providencia           1.0
#
#        MONTO_FAM  MONTO_COPAGO
# 0            890           900
# 1            630          1390
# 2            630          1390
# 3            630          1390
# 4            630          1390
# ...          ...           ...
# 99995       9330         15550
# 99996       9330         15550
# 99997       9330         15550
# 99998       9330         15550
# 99999       9330         15550
#
# [99823 rows x 13 columns]

# %%
df_MLE_limpio['CODIGO_PRESTACIÓN'] = df_MLE_limpio['CODIGO_PRESTACIÓN'].astype(str)
nombre_codigos["CODIGO_PRESTACIÓN"] = nombre_codigos["CODIGO_PRESTACIÓN"].astype(str)

df_MLE_limpio = df_MLE_limpio.merge(nombre_codigos, left_on="CODIGO_PRESTACIÓN", right_on="CODIGO_PRESTACIÓN", how='left')
# Out:
# C:\Users\benja\AppData\Local\Temp\ipykernel_6440\142898981.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nombre_codigos["CODIGO_PRESTACIÓN"] = nombre_codigos["CODIGO_PRESTACIÓN"].astype(str)

# %%
df_MLE_limpio.sample(5)
# Out:
#        MES_EMISION CODIGO_PRESTACIÓN             DESC_SECCION  \
# 58821       202311            101310          Atención Médica
# 20402       202305            101001          Atención Médica
# 43579       202306            404016  Exámenes De Diagnóstico
# 53991       202305            306011  Exámenes De Diagnóstico
# 33523       202303            302076  Exámenes De Diagnóstico
#
#                  DESC_ITEM  CODIGO_BENEFICIARIO TRAMO_FONASA    EDAD_TRAMO  \
# 58821      Consulta Médica             74220995            D  15 a 19 años
# 20402      Consulta Médica             75279392            D  25 a 29 años
# 43579         Imagenología             69093380            B  45 a 49 años
# 53991  Laboratorio Clínico             83446317            B  20 a 24 años
# 33523  Laboratorio Clínico             74522208            B  75 a 79 años
#
#          SEXO                             REGION_EMISION COMUNA_EMISION  \
# 58821  Hombre                                De Coquimbo      La Serena
# 20402   Mujer                  Metropolitana De Santiago     San Miguel
# 43579   Mujer  Del Libertador General Bernardo O'Higgins     Santa Cruz
# 53991   Mujer                              De Valparaíso   Viña Del Mar
# 33523   Mujer                                De Los Ríos       Valdivia
#
#        PRESTACIONES  MONTO_FAM  MONTO_COPAGO  \
# 58821           2.0      21020         14020
# 20402           1.0       6600          7180
# 43579           1.0       8750         19270
# 53991           1.0       1730          3810
# 33523           1.0       4510          9920
#
#                                        NOMBRE_PRESTACIÓN
# 58821  CONSULTA MEDICA DE ESPECIALIDAD EN TRAUMATOLOG...
# 20402  CONSULTA MEDICINA GENERAL                     ...
# 43579  ECOGRAFIA PARTES BLANDAS O MUSCULOESQUELETICA ...
# 53991  UROCULTIVO, RECUENTO DE COLONIAS Y ANTIBIOGRAM...
# 33523  PERFIL HEPATICO (INCLUYE TIEMPO DE PROTROMBINA...

# %%
#guardaremos el dataframe limpio en un archivo csv
if original2 == True:
    df_MLE_limpio.to_csv("../data/MLE_2023_original_limpio.csv", encoding='latin1', index=False)
elif original2 == False:
    df_MLE_limpio.to_csv("../data/sample/MLE_2023_sample_limpio.csv", encoding='latin1', index=False)

# %%
df_MLE_limpio
# Out:
#        MES_EMISION CODIGO_PRESTACIÓN             DESC_SECCION  \
# 0           202305            309022  Exámenes De Diagnóstico
# 1           202305            302023  Exámenes De Diagnóstico
# 2           202305            302023  Exámenes De Diagnóstico
# 3           202305            302023  Exámenes De Diagnóstico
# 4           202305            302023  Exámenes De Diagnóstico
# ...            ...               ...                      ...
# 99818       202308            101202          Atención Médica
# 99819       202308            101203          Atención Médica
# 99820       202306            101209          Atención Médica
# 99821       202306            101209          Atención Médica
# 99822       202306            101209          Atención Médica
#
#                  DESC_ITEM  CODIGO_BENEFICIARIO TRAMO_FONASA    EDAD_TRAMO  \
# 0      Laboratorio Clínico             97481406            D  35 a 39 años
# 1      Laboratorio Clínico             76712895            X  50 a 54 años
# 2      Laboratorio Clínico             69353764            B  50 a 54 años
# 3      Laboratorio Clínico             76007327            B  55 a 59 años
# 4      Laboratorio Clínico             81474165            B  55 a 59 años
# ...                    ...                  ...          ...           ...
# 99818      Consulta Médica             76391769            D  85 a 89 años
# 99819      Consulta Médica             75506267            D  85 a 89 años
# 99820      Consulta Médica             81255758            D  25 a 29 años
# 99821      Consulta Médica             78171390            D  40 a 44 años
# 99822      Consulta Médica             74643652            B  30 a 34 años
#
#          SEXO             REGION_EMISION COMUNA_EMISION  PRESTACIONES  \
# 0       Mujer  Metropolitana De Santiago    La Cisterna           1.0
# 1      Hombre                De Tarapacá        Iquique           1.0
# 2       Mujer  Metropolitana De Santiago    San Joaquín           1.0
# 3       Mujer                 Del Bíobío    Curanilahue           1.0
# 4       Mujer  Metropolitana De Santiago     Las Condes           1.0
# ...       ...                        ...            ...           ...
# 99818   Mujer              De Valparaíso  Villa Alemana           1.0
# 99819   Mujer                De Tarapacá          Arica           1.0
# 99820   Mujer                De Los Ríos       Valdivia           1.0
# 99821   Mujer                  Del Maule         Curicó           1.0
# 99822   Mujer  Metropolitana De Santiago    Providencia           1.0
#
#        MONTO_FAM  MONTO_COPAGO  \
# 0            890           900
# 1            630          1390
# 2            630          1390
# 3            630          1390
# 4            630          1390
# ...          ...           ...
# 99818       9330         15550
# 99819       9330         15550
# 99820       9330         15550
# 99821       9330         15550
# 99822       9330         15550
#
#                                        NOMBRE_PRESTACIÓN
# 0      ORINA COMPLETA, (INCLUYE COD. 03-09-023 Y 03-0...
# 1      CREATININA EN SANGRE                          ...
# 2      CREATININA EN SANGRE                          ...
# 3      CREATININA EN SANGRE                          ...
# 4      CREATININA EN SANGRE                          ...
# ...                                                  ...
# 99818  CONSULTA MEDICA DE ESPECIALIDAD EN GERIATRIA  ...
# 99819  CONSULTA MEDICA DE ESPECIALIDAD EN NEUROCIRUGI...
# 99820  CONSULTA MEDICA DE ESPECIALIDAD EN NEUROLOGIA ...
# 99821  CONSULTA MEDICA DE ESPECIALIDAD EN NEUROLOGIA ...
# 99822  CONSULTA MEDICA DE ESPECIALIDAD EN NEUROLOGIA ...
#
# [99823 rows x 14 columns]
